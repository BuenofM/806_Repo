# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
from scipy.stats import norm

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.93300653 2.91374884 2.91322272 2.54444359 2.4719864  2.80861262
#  2.15226041 2.9543869  2.52335952 2.60134143]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def udrn_generator(bottom, ceiling, count):
    x = uniform.rvs(size=count)
    a = bottom
    b = ceiling
    randoms  = a + (b-a)*x
    return randoms

# %%
udrn_generator(10,15,100)
# Out:
# array([12.82100657, 13.30978385, 12.47055474, 10.07786796, 11.93914751,
#        11.6154121 , 10.61705161, 12.45920454, 11.9193134 , 10.82996852,
#        14.80937533, 11.63715913, 14.34474097, 14.66763832, 13.21932803,
#        13.32113458, 14.90402632, 12.59323754, 12.01947473, 10.01564882,
#        10.74157425, 13.88179177, 14.20045693, 12.67411158, 11.83840113,
#        10.7428471 , 14.77130211, 14.31705014, 10.61272989, 12.8973106 ,
#        14.09533709, 13.65818748, 11.26905147, 12.31904759, 13.05786601,
#        12.81485615, 13.19864907, 13.21971488, 10.58326722, 12.5896907 ,
#        11.05837259, 13.9554228 , 10.76205331, 14.40615292, 12.17344948,
#        12.09065369, 11.60600132, 10.18188065, 14.61799554, 12.32440101,
#        11.15570386, 14.39160883, 11.05413863, 13.13279479, 10.25269781,
#        13.33065386, 12.78606046, 11.77139377, 12.48709917, 14.67678992,
#        11.6211479 , 11.75186455, 12.90412862, 13.16302909, 14.83508714,
# ...

# %%
udrn_generator(10,60,1000)
# Out:
# array([22.45259772, 10.24317602, 15.27893005, 41.34445784, 10.56297577,
#        50.05872293, 23.06143429, 51.39227436, 30.923359  , 43.74195153,
#        44.39976826, 41.23029346, 25.58333095, 48.27333249, 49.05869702,
#        43.23967873, 35.19691302, 14.07973258, 24.63692395, 48.71535814,
#        15.12480343, 48.5241027 , 49.54861391, 19.7813004 , 43.26893246,
#        27.44600012, 53.73346513, 54.70939703, 39.59201852, 31.8775537 ,
#        14.87903526, 12.58350545, 11.8054698 , 45.56619286, 39.80680634,
#        34.18959151, 57.48472777, 15.09343764, 43.76785197, 32.35747706,
#        29.33965117, 35.21833393, 36.26453916, 34.08371984, 36.47673201,
#        19.19357216, 57.05856158, 25.59748991, 24.81571771, 15.62904927,
#        27.32538067, 49.020707  , 21.89226908, 40.18663677, 59.90087405,
#        49.3132527 , 37.15811436, 51.05206166, 23.71861474, 50.14610436,
#        17.36297679, 46.31014687, 17.07505355, 34.00030931, 47.06879293,
# ...

# %%
sns.distplot(udrn_generator(10,15,100))

# %%
sns.distplot(udrn_generator(10,60,1000))

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
def ndrn_generator(avg, stdev, count):
    ndrn = np.random.normal(avg, stdev, size=count)
    return ndrn

# %%
ndrn_generator(10,1,1000)
# Out:
# array([10.17853505,  9.05763672,  8.90481142, 10.62495193,  9.5092815 ,
#         9.63978007, 10.43176244, 10.51122501,  9.72274167, 11.46016824,
#        12.99028965,  9.69505427,  9.53635625,  8.7091217 , 10.87192583,
#        10.32097725, 10.85970239,  9.01063375, 10.68085663,  9.5526007 ,
#         9.5559281 , 10.61001025, 10.48084523,  9.78481722,  9.07731459,
#         9.77891656,  9.13112698,  9.55214407, 11.49855015, 10.25740252,
#         9.32798855, 10.66020063, 10.84771576, 10.49698339, 10.24481596,
#         8.80992831, 10.16736319,  9.74653579,  9.61169657,  9.82375555,
#         9.9500208 , 11.06165923,  9.99601392, 10.55146539,  8.65275477,
#        10.17178129, 10.52418048, 10.10631843, 12.20340221, 10.55741889,
#         9.30914343, 11.21874629, 10.01648772, 10.75588922, 10.80027635,
#        11.13462598,  9.82887833, 10.66944365,  7.95422536, 10.00368038,
#        11.80604246, 10.0942231 , 11.26302939, 10.70879907, 10.55495245,
# ...

# %%
sns.distplot(ndrn_generator(10,1,1000))

# %%
ndrn_generator(10,50,1000)
# Out:
# array([-4.17829912e+01, -3.47688607e+01,  3.08309308e+01,  5.16598594e+01,
#         6.70015098e+00,  4.35210920e+01, -8.17666122e-01,  4.11592016e+01,
#        -3.80447942e+01, -2.26201514e+01,  2.77021997e+00,  1.51247112e+01,
#        -8.62204117e+01,  1.54297320e+01, -2.81269340e+01, -8.39150388e+01,
#         3.91982839e+00,  1.05739744e+02,  3.60884083e+01, -9.06042456e+01,
#        -1.20320609e+01, -8.67572812e+01,  2.30167539e+01,  3.47794169e+01,
#        -2.65799021e+00,  8.59564450e+01, -1.08089792e+02,  3.12435417e+01,
#         1.89506866e+01,  9.87765117e+01,  9.68099406e+01,  6.10655119e+01,
#        -4.25639299e+01,  7.56807178e+01, -5.22836634e+01,  3.20169250e+01,
#         1.82739641e+01, -8.45723598e+01, -1.44157800e+01,  5.30123736e+01,
#         4.83541987e+01,  4.58003640e+01,  9.94813305e+01, -7.14416942e+01,
#         9.31926200e+01, -4.45990948e+01, -6.92582171e+01,  4.83305008e+01,
# ...

# %%
sns.distplot(ndrn_generator(10,50,1000))

# %%
#correction
def norm_generator(mu, sigma, count):
    return norm.rvs(mu,sigma,count)

# %%
plt.hist(norm_generator(10,1,1000))
plt.hist(norm_generator(10,50,1000))
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.

# %%
vdata = pd.read_csv('/Users/manuelabueno/Documents/3_School/Ironhack-Bootcamp/Week2/vehicles/vehicles.csv')
vdata
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
vdata.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %% [markdown]
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
vdata.hist(column='Fuel Barrels/Year')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f81db375c90>]],
#       dtype=object)

# %%
vdata['Fuel Barrels/Year'].hist(bins=20)

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
vdata.hist(column='CO2 Emission Grams/Mile')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd1e098ef10>]],
#       dtype=object)

# %%
vdata['CO2 Emission Grams/Mile'].hist(bins=20)

# %% [markdown]
# 3. Combined MPG

# %%
vdata.hist(column='Combined MPG')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd1df695810>]],
#       dtype=object)

# %%
vdata['Combined MPG'].hist(bins=20)

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
#we check if there would be a bell curve

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def list_ned_generator(size):
    mean = 10
    dec=1/mean
    return expon.rvs.

# %%
list_ned_generator(1.0, 1)
# Out:
# array([1.59382908])

# %%
sns.distplot(list_ned_generator(1.0, 1))
plt.show()

# %%
list_ned_generator(1.0, 100)
# Out:
# array([2.41844151e+00, 7.38662386e-01, 2.66680719e-01, 1.38969325e+00,
#        5.85530296e-01, 1.02737693e-01, 7.50464619e-04, 7.04783483e+00,
#        1.19526659e+00, 2.20185253e+00, 3.59165236e+00, 1.71174524e-01,
#        1.35335267e+00, 4.90893168e-01, 1.79137554e+00, 4.14789871e-01,
#        1.06557818e+00, 1.15779788e+00, 8.15161057e-01, 1.93203398e-02,
#        4.20701818e-01, 1.72636233e+00, 1.09740524e+00, 1.07303988e+00,
#        1.12631411e+00, 9.31180917e-02, 9.97758723e-01, 4.04391728e+00,
#        1.19516276e+00, 1.06933639e+00, 2.58035317e-01, 3.75260377e+00,
#        1.69909852e-01, 1.91704350e+00, 8.76731813e-02, 2.82819153e-01,
#        5.51761744e-01, 8.31101842e-01, 1.03310004e+00, 2.99290742e-02,
#        4.40151771e-01, 1.51879727e+00, 8.54257021e-01, 1.41089766e+00,
#        3.26769984e+00, 1.91464660e+00, 2.30671290e-01, 8.91213494e-01,
#        1.00517811e+00, 1.26833252e+00, 3.84218967e+00, 7.02683507e-01,
# ...

# %%
sns.distplot(list_ned_generator(1.0, 100))
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
expon.cdf(x=15,scale=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-0098ba5167b5> in <module>
# ----> 1 expon.cdf(x=15,scale=10)
#
# NameError: name 'expon' is not defined

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
