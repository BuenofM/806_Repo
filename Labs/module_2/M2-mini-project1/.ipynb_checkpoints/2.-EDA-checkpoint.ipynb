# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('/Users/manuelabueno/Documents/3_School/Ironhack-Bootcamp/806_Repo/Labs/module_2/M2-mini-project1/diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
diamonds.describe()
# Out:
#               carat       clarity         color             x             y  \
# count  53932.000000  53932.000000  53932.000000  53932.000000  53932.000000
# mean       0.797879      3.051101      3.405789      5.732007      5.734141
# std        0.473986      1.647109      1.701165      1.119670      1.113272
# min        0.200000      0.000000      0.000000      3.730000      3.680000
# 25%        0.400000      2.000000      2.000000      4.710000      4.720000
# 50%        0.700000      3.000000      3.000000      5.700000      5.710000
# 75%        1.040000      4.000000      5.000000      6.540000      6.540000
# max        5.010000      7.000000      6.000000     10.740000     19.280000
#
#                   z         depth         table         price
# count  53932.000000  53932.000000  53932.000000  53932.000000
# mean       3.539735     61.749336     57.457029   3932.136079
# std        0.692051      1.432514      2.234064   3988.734835
# min        1.070000     43.000000     43.000000    326.000000
# 25%        2.910000     61.000000     56.000000    949.750000
# 50%        3.530000     61.800000     57.000000   2401.000000
# 75%        4.040000     62.500000     59.000000   5324.000000
# max        8.060000     79.000000     95.000000  18823.000000

# %%
print("""
Variability = Dispersion

Examples of measures of statistical dispersion: 
- variance
- standard deviation (if the data points are further from the mean, there is a higher deviation within the data set)
- interquartile range
""")
# Out:
# Variability = Dispersion
#
# Examples of measures of statistical dispersion:
# - variance
# - standard deviation (if the data points are further from the mean, there is a higher deviation within the data set)
# - interquartile range

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#'carat', 'clarity', 'color' ?

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
diamonds.groupby('color').mean()
# Out:
#           carat   clarity         x         y         z      depth      table  \
# color
# 0      1.162137  2.776353  6.519338  6.518105  4.033251  61.887215  57.812393
# 1      1.026927  2.964035  6.222826  6.222730  3.846369  61.846385  57.577278
# 2      0.911627  2.933871  5.984776  5.981484  3.699147  61.836557  57.518176
# 3      0.771088  3.463419  5.678549  5.681198  3.507966  61.757449  57.288060
# 4      0.736509  3.134605  5.616727  5.620529  3.465938  61.694087  57.433148
# 5      0.657867  2.969889  5.411580  5.416949  3.337767  61.662090  57.491201
# 6      0.657715  2.691025  5.417851  5.421928  3.343320  61.698066  57.404355
#
#              price
# color
# 0      5323.818020
# 1      5091.874954
# 2      4484.958805
# 3      3998.145173
# 4      3725.091938
# 5      3076.752475
# 6      3168.106436

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
print("""
The less color (so the closer to 0) the higher the price is.""")
# Out:
# The less color (so the closer to 0) the higher the price is.

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
diamonds['color'].plot.box()

# %%
print("""
Most of the diamonds are in the shades 2 to 5.
""")
# Out:
# Most of the diamonds are in the shades 2 to 5.

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
diamonds.groupby('carat').mean()
# Out:
#         clarity     color          x          y         z      depth  \
# carat
# 0.20   2.833333  5.166667   3.786667   3.753333  2.303333  61.100000
# 0.21   2.666667  5.444444   3.874444   3.837778  2.332222  60.511111
# 0.22   2.600000  4.800000   3.898000   3.848000  2.386000  61.620000
# 0.23   4.901024  4.518771   3.946382   3.973379  2.431468  61.426621
# 0.24   4.972441  4.185039   3.990157   4.019331  2.465591  61.599213
# ...         ...       ...        ...        ...       ...        ...
# 4.00   0.000000  1.000000  10.010000   9.940000  6.310000  63.300000
# 4.01   0.000000  0.500000  10.080000  10.020000  6.205000  61.750000
# 4.13   0.000000  2.000000  10.000000   9.850000  6.430000  64.800000
# 4.50   0.000000  0.000000  10.230000  10.160000  6.720000  65.800000
# 5.01   0.000000  0.000000  10.740000  10.540000  6.980000  65.500000
#
#            table         price
# carat
# 0.20   59.333333    365.166667
# 0.21   58.444444    380.222222
# 0.22   60.400000    391.400000
# 0.23   58.034130    486.143345
# 0.24   57.488189    505.185039
# ...          ...           ...
# 4.00   58.000000  15984.000000
# 4.01   61.500000  15223.000000
# 4.13   61.000000  17329.000000
# 4.50   58.000000  18531.000000
# 5.01   59.000000  18018.000000
#
# [273 rows x 8 columns]

# %%
print("""
The relationship between carat and price is quite obvious.
As the weight of the diamond gets bigger, the price grows.
""")
# Out:
# The relationship between carat and price is quite obvious.
# As the weight of the diamond gets bigger, the price grows.

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
pc = diamonds.pivot_table(index=['carat'], values='price', aggfunc='mean')
pc
# Out:
#               price
# carat
# 0.20     365.166667
# 0.21     380.222222
# 0.22     391.400000
# 0.23     486.143345
# 0.24     505.185039
# ...             ...
# 4.00   15984.000000
# 4.01   15223.000000
# 4.13   17329.000000
# 4.50   18531.000000
# 5.01   18018.000000
#
# [273 rows x 1 columns]

# %%
plt.plot(pc)

#Labels (to be provided) for x and y
plt.xlabel('Carat')
plt.ylabel('Price')

#Title(to be provided)
plt.title('Price Compared to Carat')

plt.show()

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
diamonds.groupby('table').mean()
# Out:
#         carat  clarity  color      x      y      z  depth    price
# table
# 43.0   1.0400     4.00    1.0  6.450  6.410  4.040  62.90   4997.0
# 44.0   0.2900     4.00    5.0  4.200  4.240  2.650  62.80    474.0
# 49.0   0.6500     3.00    3.0  5.355  5.320  3.425  64.25   2290.5
# 50.0   1.5100     2.00    3.0  7.380  7.295  4.510  61.50   8995.5
# 50.1   0.9400     1.00    2.0  6.130  6.170  4.060  66.00   3353.0
# ...       ...      ...    ...    ...    ...    ...    ...      ...
# 71.0   0.6800     2.00    3.0  5.850  5.700  3.350  58.00   1633.0
# 73.0   0.6025     3.25    4.5  5.520  5.465  3.745  68.90   2406.5
# 76.0   0.7900     2.00    3.0  5.520  5.130  3.350  65.30   2362.0
# 79.0   0.8100     1.00    4.0  5.260  5.200  3.580  68.80   2301.0
# 95.0   2.0100     2.00    4.0  8.320  8.310  4.870  58.60  13387.0
#
# [127 rows x 8 columns]

# %%
print("""
Table doesn't seem to be a related to price.
""")

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
diamonds.groupby('clarity').mean()
# Out:
#             carat     color         x         y         z      depth  \
# clarity
# 0        1.283846  2.968961  6.761093  6.709379  4.224688  62.734278
# 1        1.077602  3.469967  6.404157  6.395579  3.952642  61.771567
# 2        0.850482  3.448450  5.888383  5.888256  3.640636  61.853042
# 3        0.763850  3.494370  5.658633  5.659782  3.492788  61.724249
# 4        0.727108  3.161812  5.572860  5.580017  3.437924  61.667968
# 5        0.596202  3.569483  5.218454  5.232118  3.221465  61.663778
# 6        0.503131  3.350848  4.961721  4.976437  3.062132  61.624521
# 7        0.505123  3.101676  4.968402  4.989827  3.061659  61.510615
#
#              table        price
# clarity
# 0        58.303779  3924.168691
# 1        57.926823  5062.267356
# 2        57.662541  3996.001148
# 3        57.418040  3924.166204
# 4        57.313966  3839.144308
# 5        57.024990  3283.737071
# 6        56.883881  2519.512315
# 7        56.507207  2864.839106

# %%
print("""
Clarity doesn't seem to be related to price.
""")

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8493658995804609

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
